# %% [markdown]
# # Summer School for Women in AI and Data Sceince
# ---
# ---
# # <span style="color:blue">Natural Language Processing</span>
#  ---
# ## -  <span style="color:red">Seid Muhie Yimam  - UHH, HCDS</span>
# ## -  <span style="color:red">Hellina Hailu Negatu -  University of Berkeley</span>
# ---
# ---

# %% [markdown]
# # Topics
# - Introduction to Natural Language Processing
# - Natrual Language Processing Toolkits
# - Text Processing Frameworks
# - Large Language Models and Transformers
# - NLP Research and EthioNLP
# - Advanced NLP and Research

# %% [markdown]
# ## Introduction to Natural Language Processing
#  - Enable to interact with a computer - understand human language
#  - Why it is difficult for computers to understand human languages?
#     - Human language is ambigous
#     - Computer are good in processing formal languages
#  - Examples of NLP applications
#     - Speech to text and text to speech
#     - Question answering
#     - Information extraction
#     - Text summarization
#     - ...

# %% [markdown]
# ## Why NLP
# - Natural language is complex
# - Examples
#    -  <span style="color:red"> I saw the man on the hill with a telescope </span>

# %% [markdown]
# ![](https://64.media.tumblr.com/d6552ff51881937371c94dc18865d711/tumblr_mo1nl6Nt9n1rwewyjo1_400.jpg)

# %% [markdown]
# 1. I saw the man. The man was on the hill. I was using a telescope.
# 1. I saw the man. I was on the hill. I was using a telescope.
# 1. I saw the man. The man was on the hill. The hill had a telescope.
# 1. I saw the man. I was on the hill. The hill had a telescope.
# 1. I saw the man. The man was on the hill. I saw him using a telescope.

# %% [markdown]
# ## Basic NLP tasks
#  - Tokenization and segmentation
#  - Stemming and Lemmatization
#  - Parsing

# %% [markdown]
# # Existing NLP frameworks in Python
# - NLTK
# - spaCy
#
# ## Python preprocessing and NLP pipeline
# <span style="color:blue">NLTK</span> and <span style="color:blue">spaCy</span> are packages/libraries that are important for preprocessing and NLP pipeline.

# %% [markdown]
# ## Installing NLTK components
# <span style="color:blue">NLTK</span> is installed automatically with the Anaconda distribution. However, different modules, datasets, and packages are left for the user to download <span style="color:blue">on demand</span>. Try running the following code to install some or all the required resources. If you already have the required resources, the program should run without any problem. Otherwise, it will give an error with hints on how to install the missing resources.
#
# Example of installing missed resources:
# >```import nltk```
#
# >```nltk.download('punkt')```

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# If you want to choose from a graphical user interface, run the following from the command line
#
# >```nltk.download()```
#
# Then you can choose what you like to download. You can download everything but it will take more time and storage.
#
# To install all the packages/resources automatically, run the following
# >```nltk.download('all')```

# %%
import nltk
#Download specific resources
nltk.download('gutenberg')
nltk.download('genesis')
nltk.download('inaugural')
nltk.download('nps_chat')
nltk.download('webtext')
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package genesis to /root/nltk_data...
# [nltk_data]   Package genesis is already up-to-date!
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# [nltk_data] Downloading package nps_chat to /root/nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# [nltk_data] Downloading package webtext to /root/nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# True

# %% [markdown]
# The NLTK resource contains dataset that are annotated for different linguistic annotation tasks such as **POS tagging**, **dependency parsing**, **NER** ...

# %%
# Show all books from nltk
from nltk.book import *
#the books are available as text1---text9
print (text1.name)
print("----")
print (text1.concordance("monstrous"))
print ("----")
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# Moby Dick by Herman Melville 1851
# ----
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# ...

# %% [markdown]
# NLTK also include `inaugural speeches` of US presidents.
#
# You can import these corpora as follows
# >``` from nltk.corpus import inaugural```

# %%
from nltk.corpus import inaugural
# print all inaugural
print("Inaugral Texts:",inaugural.fileids())
inaugural.raw("2017-Trump.txt")[:1000]
# Out:
# Inaugral Texts: ['1789-Washington.txt', '1793-Washington.txt', '1797-Adams.txt', '1801-Jefferson.txt', '1805-Jefferson.txt', '1809-Madison.txt', '1813-Madison.txt', '1817-Monroe.txt', '1821-Monroe.txt', '1825-Adams.txt', '1829-Jackson.txt', '1833-Jackson.txt', '1837-VanBuren.txt', '1841-Harrison.txt', '1845-Polk.txt', '1849-Taylor.txt', '1853-Pierce.txt', '1857-Buchanan.txt', '1861-Lincoln.txt', '1865-Lincoln.txt', '1869-Grant.txt', '1873-Grant.txt', '1877-Hayes.txt', '1881-Garfield.txt', '1885-Cleveland.txt', '1889-Harrison.txt', '1893-Cleveland.txt', '1897-McKinley.txt', '1901-McKinley.txt', '1905-Roosevelt.txt', '1909-Taft.txt', '1913-Wilson.txt', '1917-Wilson.txt', '1921-Harding.txt', '1925-Coolidge.txt', '1929-Hoover.txt', '1933-Roosevelt.txt', '1937-Roosevelt.txt', '1941-Roosevelt.txt', '1945-Roosevelt.txt', '1949-Truman.txt', '1953-Eisenhower.txt', '1957-Eisenhower.txt', '1961-Kennedy.txt', '1965-Johnson.txt', '1969-Nixon.txt', '1973-Nixon.txt', '1977-Carter.txt', '1981-Reagan
# ...

# %% [markdown]
# ## spaCy
# <span style="color:blue">spaCy</span> is a free, open-source library for advanced Natural Language Processing (NLP) in Python.
# It is a package, with a support for a number of <span style="color:blue">nlp</span> tasks such as tokenization, lemmatisation, part-of-speech tagging, entity recognition and so on.
#
# ![](https://spacy.io/images/pipeline.svg)

# %% [markdown]
# ### How to Install spaCy
# To install spaCy, visit the documentation page [here](https://spacy.io/usage)
# ### Using pip
# >`pip install -U spacy`
#  ### If you want to install it from the notebook, append the `!` before the command
#  > `!pip install -U spacy`

# %% [markdown]
# To install some models, run the following from the command line (make sure to use the correct python version, that is python3)
# > `python3 -m spacy download en_core_web_sm`
#
# or
#
# >`python3 -m spacy download en`
#
# `en_core_web_sm`: (11 MB) English multi-task CNN trained on <span style="color:blue">OntoNotes</span>. Assigns context-specific token vectors, POS tags, dependency parse and named entities.

# %% [markdown]
# `en_core_web_md`: (91 MB) English multi-task CNN trained on <span style="color:blue">OntoNotes</span>, with GloVe vectors trained on Common Crawl. Assigns word vectors, context-specific token vectors, POS tags, dependency parse and named entities.
#
# `en_core_web_lg`: (789 MB) English multi-task CNN trained on <span style="color:blue">OntoNotes</span>, with GloVe vectors trained on Common Crawl. Assigns word vectors, context-specific token vectors, POS tags, dependency parse and named entities.

# %%
# !pip install -U spacy

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 49.3 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# start spaCy’s pipeline, which can load differnt spacy models
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("The big grey dog ate all of the chocolate, but fortunately the he wasn't sick!")
#Tokenization
print("Using split", doc.text.split())
#Using spaCy, only orth_ method
print("Using spaCy",[token.orth_ for token in doc])
# using spacy, including the integer representation of tokens
print("spaCy integer",[(token, token.orth_, token.orth) for token in doc] )
# Out:
# Using split ['The', 'big', 'grey', 'dog', 'ate', 'all', 'of', 'the', 'chocolate,', 'but', 'fortunately', 'the', 'he', "wasn't", 'sick!']
# Using spaCy ['The', 'big', 'grey', 'dog', 'ate', 'all', 'of', 'the', 'chocolate', ',', 'but', 'fortunately', 'the', 'he', 'was', "n't", 'sick', '!']
# spaCy integer [(The, 'The', 5059648917813135842), (big, 'big', 15511632813958231649), (grey, 'grey', 10475807793332549289), (dog, 'dog', 7562983679033046312), (ate, 'ate', 10806788082624814911), (all, 'all', 13409319323822384369), (of, 'of', 886050111519832510), (the, 'the', 7425985699627899538), (chocolate, 'chocolate', 10946593968795032542), (,, ',', 2593208677638477497), (but, 'but', 14560795576765492085), (fortunately, 'fortunately', 13851269277375979931), (the, 'the', 7425985699627899538), (he, 'he', 1655312771067108281), (was, 'was', 9921686513378912864), (n't, "n't", 2043519015752540944), (sick, 'sick', 14841597609857081305), (!, '!', 17494803046312582752)]

# %% [markdown]
# # Dependency parssing using spaCy

# %%
from spacy import displacy
doc = nlp(u'This is a sentence.')
#doc = nlp(u'I saw the man on the hill with a telescope.')
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3d340ba576b84ab383b27f5d9670b068-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %% [markdown]
# # Important functions for language processing

# %%
# conditioning
words = ["the", "quick", "brown", "fox",",", "jumps", "over", "the", "lazy", "dog","!" ]
punct ="!.,"
for word in words:
    if word in punct:
        print (word + " is a punctuation", end="\n")
# Out:
# , is a punctuation
# ! is a punctuation

# %%
# Zip (concatenate lists). Example words, frequencies, POS Tag
print()
print("---")
words = ['I', 'turned', 'off', 'the', 'spectroroute']
freq = [15, 3,6,23,1]
tags = ['noun', 'verb', 'prep', 'det', 'noun']
print ("Zipped:",  list(zip(words, tags, freq)))
print("---")
# Out:
# ---
# Zipped: [('I', 'noun', 15), ('turned', 'verb', 3), ('off', 'prep', 6), ('the', 'det', 23), ('spectroroute', 'noun', 1)]
# ---

# %%
# Sorting, reversing, differences
words_on = ['I', 'turned', 'on', 'the', 'light']
print ("sorted:", sorted(words))
print ("reveresed:",list(reversed(words)))
print ("difference:", set(words).difference(words_on))
print ("difference:",set(words_on).difference(words))
print("---")
# Out:
# sorted: ['I', 'off', 'spectroroute', 'the', 'turned']
# reveresed: ['spectroroute', 'the', 'off', 'turned', 'I']
# difference: {'off', 'spectroroute'}
# difference: {'light', 'on'}
# ---

# %% [markdown]
# ## <span style="color:blue">Splitting datasets:</span>
#
# We usually use existing tools or frameworks to split datasets (we will discuss in Machine learning class).

# %%
text = """
This is a simple training example.
We split by the text into training and test sets.
Most of the data goes to training.
Small parts for testing
"""
split = int(0.9 * len(text.split()))
train, test = text.split()[:split], text.split()[split:]
print ("train set",train)
print("test set", test)
# Out:
# train set ['This', 'is', 'a', 'simple', 'training', 'example.', 'We', 'split', 'by', 'the', 'text', 'into', 'training', 'and', 'test', 'sets.', 'Most', 'of', 'the', 'data', 'goes', 'to', 'training.', 'Small']
# test set ['parts', 'for', 'testing']

# %% [markdown]
# <span style="color:blue">Generator</span>
#
# Assume you are searching a given word in a corpus
# > ```
#  def search1(substring, words):
#     result = []
#     for word in words:
#         if substring in word:
#             result.append(word)
#     return result
#
#
# Here in <span style="color:blue">search1</span>, the list is <span style="color:blue">accumulated</span> and the final result is returned once the search is over. What if the file is <span style="color:red">very large</span>...?

# %%
# Lets use the Brown corpus from nltk to search words
nltk.download('brown')
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
import nltk
def search1(substring, words):
    result = []
    for word in words:
        if substring in word:
            result.append(word)
    return result

for item in search1('zzo', brown.words()):
    print(item, end="\n")
# Out:
# Palazzo
# Palazzo
# Palazzo
# Palazzo
# palazzo
# palazzo
# Palazzo
# Palazzo
# Palazzo
# palazzo
# Palazzo
# palazzo
# Piazzo
# mezzo
# palazzos

# %% [markdown]
# >```
#  def search2(substring, words):
#     for word in words:
#         if substring in word:
#             yield word
#
# Here, <span style="color:blue">search2</span> uses a <span style="color:blue">yield</span> statement, which is a <span style="color:blue">generator</span>. It will pause when it get the first word and the caller function will do whatever with the search word before search continues.

# %%
def search2(substring, words):
    for word in words:
        if substring in word:
            yield word
for item in search2('zzo', brown.words()):
    print(item, "\n")
# Out:
# Palazzo
#
# Palazzo
#
# Palazzo
#
# Palazzo
#
# palazzo
#
# palazzo
#
# Palazzo
#
# Palazzo
#
# Palazzo
#
# palazzo
#
# Palazzo
#
# palazzo
#
# Piazzo
#
# mezzo
#
# palazzos

# %% [markdown]
#  ## Procedural and declarative style
# Example, count the average length of a token

# %%
#Procedural - average word length
tokens = brown.words(categories='news')
count = 0
total = 0
for token in tokens:
    count += 1
    total += len(token)
print(total / count)
# Out:
# 4.401545438271973

# %%
#Declarative - average word length
tokens = brown.words(categories='news')
print (sum(len(t) for t in tokens)/len(tokens))
# Out:
# 4.401545438271973

# %%
# Procedural - longest word
text = nltk.corpus.gutenberg.words('milton-paradise.txt')
longest = ''
for word in text:
    if len(word) > len(longest):
        longest = word
print(longest) # Print the longest word (ONLY one).
# Out:
# unextinguishable

# %%
# Procedural - longest word
maxlen = max(len(word) for word in text)# find longest word length
print([word for word in text if len(word) == maxlen]) # print those words
# Out:
# ['unextinguishable', 'transubstantiate', 'inextinguishable', 'incomprehensible']

# %% [markdown]
# # Information extraction workflow
# ## Raw text <span style="color:red">--></span> Sentence Segmentatio <span style="color:red">--></span> Tokenization <span style="color:red">--></span>  Part of speech tagging <span style="color:red">--></span> Entity Recognition<span style="color:red">--></span>  Relation recognition (chunks) --> Relation

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
example = "I saw the man with a telescope"

# %%
def process(sentence):
    s = nltk.word_tokenize(sentence)
    s = nltk.pos_tag(s)
    return s

# %%
sentence = process(example)
sentence
# Out:
# [('I', 'PRP'),
#  ('saw', 'VBD'),
#  ('the', 'DT'),
#  ('man', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('telescope', 'NN')]

# %% [markdown]
# # Amharic Segmenter, tokenizer, normalizer, ...
# See our implementation from here: https://github.com/uhh-lt/amharicprocessor

# %%
# !pip install amseg
# !pip install pytesseract
# !pip install pdf2image

# %%
from amseg.amharicSegmenter import AmharicSegmenter
sent_punct = []
word_punct = []
segmenter = AmharicSegmenter(sent_punct,word_punct)
words = segmenter.amharic_tokenizer("እአበበ በሶ በላ።")

# %%
print(words)
# Out:
# ['እአበበ', 'በሶ', 'በላ', '።']

# %%
sentences = segmenter.tokenize_sentence("እአበበ በሶ በላ። ከበደ ጆንያ፤ ተሸከመ፡!ለምን?")

# %%
sentences
# Out:
# ['እአበበ በሶ በላ።', 'ከበደ ጆንያ፤ ተሸከመ፡!', 'ለምን?']

# %%
from amseg.amharicNormalizer import AmharicNormalizer as normalizer
from amseg.amharicRomanizer import AmharicRomanizer as romanizer
normalized = normalizer.normalize('ሑለት ሦስት')

# %%
print(normalized)
# Out:
# ሁለት ሶስት

# %%
romanized = romanizer.romanize('ሑለት ሦስት')

# %%
print(romanized)
# Out:
# ḥulat śosət

# %%
from amseg.amharicTranslitrator import AmharicTranslitrator as  transliterator
transliterated = transliterator.transliterate('msa belash')

# %%
print(transliterated)
# Out:
# ምሳ በላሺ

# %% [markdown]
# # <span style="color:red">Exercise</span>
#
# from the following text, count how often the word "Addis" occurs?
# ```
# text = """
# አዲስ አበባ ፡ በትናንትናው ቀን የጣላው ዝናብ አዲሥ አበባ ለሚገኙ በረራዎሽ ዓዲስ ፈተና እንደሆነባቸው የ ዐዲስ አምባ ነዋሪዎች ተናገሩ። """
#
# ```

# %% [markdown]
# ## Lemmatization
# A lemma is the canonical, <span style="color:blue">uninflected</span> or <span style="color:blue">dictionary form</span> of a word. For example, the lemma of <span style="color:blue">small</span><span style="color:red">est</span> is <span style="color:blue">small,</span> and the lemma of <span style="color:blue">eat</span><span style="color:red">ing</span> is <span style="color:blue">eat.</span> In many languages, the lemma for nouns is the <span style="color:blue">nominative singula</span>r form, the lemma for adjectives is the <span style="color:blue">nominative singular</span></span> positive form, and the lemma for verbs is the <span style="color:blue">infinitive.</span> But given an inflected form, finding the lemma (a process called <span style="color:blue">lemmatization</span>) is not always as easy. Words often undergo regular spelling changes when inflected for example, in English, verbs and adjectives ending in -e often drop this letter when inflecting: <span style="color:blue">bake → baking</span>. Sometimes final consonants are doubled, as in (British) English <span style="color:blue">travel → travelling</span>.

# %% [markdown]
# An accurate algorithm for lemmatization must be aware of these sorts of inflectional rules and know how to undo them to arrive at the <span style="color:blue">base form</span> of the word. It must also know about completely irregular cases, such as <span style="color:blue">go → went</span>, <span style="color:blue">mouse → mice</span>, and <span style="color:blue">good → better</span>. Lemmatization is a difficult task for computers, and requires some basic understanding of the grammatical context and properties of the word. For example, the lemma of <span style="color:blue">dove</span> depends on whether the word is being used as a noun (as in the <span style="color:blue">bird</span>) or a verb (as in the past tense of <span style="color:blue">dive</span>).
#
# ![dove.jpg](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTugmLpw_zAyquDShQzMdRNnyHe_4-VVjS4sA&s)
#
# ---
# ![dive.png](https://ocs-sport.ams3.cdn.digitaloceanspaces.com/scotswim-full/2022/06/SCO-Grace-Reid-11-1024x683.jpg)

# %% [markdown]
# ## Stemmer
# <span style="color:blue">Stemming</span> tries to remove or chops off the end of a word to reduce the word to its base form, somehow a crude approach.
#
# Different stemmers use different rules.

# %%
import nltk
sentence = "These are simply sentences obtained from the treminals."
tokens = nltk.word_tokenize(sentence, language='english')
print(tokens)
# Out:
# ['These', 'are', 'simply', 'sentences', 'obtained', 'from', 'the', 'treminals', '.']

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Lemmatizzer
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
[lemmatizer.lemmatize(token) for token in tokens]
# Out:
# ['These',
#  'are',
#  'simply',
#  'sentence',
#  'obtained',
#  'from',
#  'the',
#  'treminals',
#  '.']

# %%
#Stemming
porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()
[porter.stem(token) for token in tokens]
# Out:
# ['these', 'are', 'simpli', 'sentenc', 'obtain', 'from', 'the', 'tremin', '.']

# %% [markdown]
# # <span style="color:red">Exercise</span>
#
# Apply `zip` and show the token, its lemma and its stem in tuple --> (token, lemma, stem)

# %% [markdown]
# ## Parts of speech tagging with NLTK
# Part-of-speech tagging (POS tagging) is the process of marking up the words in a text with their corresponding part of speech (e.g., `noun, verb, adjective`). For example, take the following sentence:
#
# The `Penn Treebank tags` used here are as follows:
# `DT` determiner `NN` noun, singular or mass `VBD` verb, past tense
# `JJS` adjective, superlative `NNS` noun, plural `VBN` verb, past participle

# %% [markdown]
# The inventory from which these POS tags are drawn varies from `language to language`, and from `application to application`.
#
# NLTK includes a Part-of-speech tagger, which assign a <span style="color:blue">tag</span>, or <span style="color:blue">word class</span>, or <span style="color:blue">lexical category</span> for a given token in a text. The default POS tagset for English is based on [<span style="color:blue">PennTreebank tagset</span>](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html).
#
# NLTK also include the [<span style="color:blue">Universal POS tagset</span>](https://universaldependencies.org/u/pos/)

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tag import pos_tag
import nltk
text = "I saw a man sawing the tree with a saw. He can't finish it ontime."
sentences = sent_tokenize(text)
for sentence in sentences:
    for token, pos in pos_tag(word_tokenize(sentence)):
        print(token +" ===> " + pos)
# Out:
# I ===> PRP
# saw ===> VBD
# a ===> DT
# man ===> NN
# sawing ===> VBG
# the ===> DT
# tree ===> NN
# with ===> IN
# a ===> DT
# saw ===> NN
# . ===> .
# He ===> PRP
# ca ===> MD
# n't ===> RB
# finish ===> VB
# it ===> PRP
# ontime ===> RB
# . ===> .

# %% [markdown]
# # Amharic POS tagging [Optional]
# https://github.com/uhh-lt/ethiopicmodels
# ![https://github.com/uhh-lt/ethiopicmodels/raw/master/logo.png](https://github.com/uhh-lt/ethiopicmodels/raw/master/logo.png)

# %%
# !pip install wget
# !pip install flair

# %%
import wget
from flair.models import SequenceTagger
from flair.data import Sentence

# First uncomment the following to download the model and comment it once downloading is completed
am_pos_model = wget.download("http://ltdata1.informatik.uni-hamburg.de/amharic/taskmodels/pos/final-model.pt")
#am_pos_model = SequenceTagger.load('final-model.pt')

# %%
# create example sentence
am_pos_model = SequenceTagger.load('final-model.pt')
sentence = Sentence('ሰውዬውን ኮረብታው ላይ በቴሌስኮፕ አየሁት ።')
# predict class and print
am_pos_model.predict(sentence)
print(sentence.to_tagged_string())
# Out:
# 2024-05-02 07:23:20,635 SequenceTagger predicts: Dictionary with 66 tags: <unk>, O, N, NUMP, NUMCR, VP, VPS, VREL, NP, PUNC, NUM, NPC, NCS, VS, V, PREP, PRONPS, AUXC, ADJ, NPS, PRONS, VRELS, NS, ADV, NC, AUX, CONJ, PRON, ADJP, VRELCS, PRONC, PRONP, PRONCS, VN, VPCS, AUXS, VC, ADVP, VCS, INT, VPC, ADJS, ADJPCS, NPCS, VNS, AUXCS, ADJC, NUMOR, VRELC, PRONPC
# Sentence[6]: "ሰውዬውን ኮረብታው ላይ በቴሌስኮፕ አየሁት ።" → ["ሰውዬውን"/N, "ኮረብታው"/N, "ላይ"/PREP, "በቴሌስኮፕ"/NP, "አየሁት"/V, "።"/PUNC]

# %%
# create example sentence
sentence = Sentence('ፈተናው ከበደን ።')
# predict class and print
am_pos_model.predict(sentence)
print(sentence.to_tagged_string())
# Out:
# Sentence[3]: "ፈተናው ከበደን ።" → ["ፈተናው"/N, "ከበደን"/V, "።"/PUNC]

# %%
# create example sentence
sentence = Sentence('ከበደን አየኸው ።')
# predict class and print
am_pos_model.predict(sentence)
print(sentence.to_tagged_string())
# Out:
# Sentence[3]: "ከበደን አየኸው ።" → ["ከበደን"/N, "አየኸው"/V, "።"/PUNC]

# %% [markdown]
# # Named Entity Recognition (NER)
#
# NER invloves identifying named entities, such as `person`, `location`, `organization`,... from a text. It can also depend on the application domain, for example, medical entities, financial entities and so on. It usually involve training a model that can detect named entities automatically.

# %%
import nltk
# Download necessary NLTK data packages
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
sample_text = "F. Henly was born in San Francisco and he works at Microsoft."
tokens = nltk.word_tokenize(sample_text)
tagged_tokens = nltk.pos_tag(tokens)
print (tagged_tokens)
# Out:
# [('F.', 'NNP'), ('Henly', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('in', 'IN'), ('San', 'NNP'), ('Francisco', 'NNP'), ('and', 'CC'), ('he', 'PRP'), ('works', 'VBZ'), ('at', 'IN'), ('Microsoft', 'NNP'), ('.', '.')]

# %%
entities = nltk.ne_chunk(tagged_tokens)
print(entities)
# Out:
# (S
#   F./NNP
#   (PERSON Henly/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE San/NNP Francisco/NNP)
#   and/CC
#   he/PRP
#   works/VBZ
#   at/IN
#   (ORGANIZATION Microsoft/NNP)
#   ./.)

# %%
# entities.draw()

# %% [markdown]
# # NER for Amharic [Optional]

# %%
# Comment this once it is downloaded
am_ner_model = wget.download("http://ltdata1.informatik.uni-hamburg.de/amharic/taskmodels/ner/final-model.pt")

# %%
from flair.data import Sentence
from flair.models import SequenceTagger


# load the model you trained
model = SequenceTagger.load(am_ner_model)
# or if you manually download the final-model.pt file do it as follows, make sure to put the correct path
#model = SequenceTagger.load('final-model.pt')
# Out:
# 2024-05-02 07:24:22,619 SequenceTagger predicts: Dictionary with 14 tags: <unk>, O, B-ORG, I-ORG, B-LOC, B-PER, I-PER, B-TTL, I-LOC, B-TIME, I-TIME, I-TTL, <START>, <STOP>

# %%
# create example sentence
sentence = Sentence('የነዳጅና ኢነርጂ ባለሥልጣን ምክትል ዋና ኃላፊ አቶ ሔኖስ ወርቁ እጥረቱን በተመለከተ ከዚህ ቀደም ጥያቄ  እንደተነሳላቸው የገለጹ ሲሆን ችግሩ ግን በቢሾፍቱ ከተማ ብቻ የተወሰነ አይደለም ብለዋል ። ')

# predict tags and print
model.predict(sentence)

print(sentence.to_tagged_string())
# Out:
# Sentence[26]: "የነዳጅና ኢነርጂ ባለሥልጣን ምክትል ዋና ኃላፊ አቶ ሔኖስ ወርቁ እጥረቱን በተመለከተ ከዚህ ቀደም ጥያቄ  እንደተነሳላቸው የገለጹ ሲሆን ችግሩ ግን በቢሾፍቱ ከተማ ብቻ የተወሰነ አይደለም ብለዋል ።" → ["አቶ"/TTL, "ሔኖስ ወርቁ"/PER, "በቢሾፍቱ ከተማ"/LOC]

# %% [markdown]
# -----
# -----
# # How to read data from web page content
# The standard <span style="color:blue">requests</span> library can be  used to retrieve content from a web page. Lets see some of the methods for the <span style="color:blue">GET</span> HTTP action. A better way of retrieving web content will be discussed later, mainly using different packages.

# %%
# !python -m pip install requests

# %%
# requests is the standard html library to make HTTP requests
import requests
link1 = "https://www.bbc.com/amharic/articles/cw4rwlpv98do"

# get is an HTTP method to retrieve data from a specified resource
# response is an HTTP "Response" object to inspect the request
response = requests.get(link1)
# HTTP status code, example 200 is an ok status, 404 is not found status code
status = response.status_code
print(status)
# Out:
# 200

# %%
# the information obtained from the resource, a payload in the form of bytes
content = response.content
print (type(content))
print("====")
print (content)
# Out:
# <class 'bytes'>
# ====
# ...

# %%
print (response.text)
# Out:
# <!doctype html><html lang="am" class="no-js" dir="ltr"><head><title data-react-helmet="true">ዓለም አቀፉ የላብ አደሮች ቀን ለምን ሚያዝያ 23 ይከበራል? - BBC News አማርኛ</title><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" charSet="utf-8"/><meta data-react-helmet="true" name="robots" content="noodp, noydir, max-image-preview:large"/><meta data-react-helmet="true" name="theme-color" content="#B80000"/><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta data-react-helmet="true" name="apple-mobile-web-app-title" content="BBC News አማርኛ"/><meta data-react-helmet="true" name="application-name" content="BBC News አማርኛ"/><meta data-react-helmet="true" name="description" content="ሜይ ዴይ በመባል በስፋት የሚታወቀው የዓለም ወዛደሮች (ላብአደሮች) ቀን በአውሮፓውያኑ አቆጣጠር በግንቦት ወር የመጀመሪያ ዕለት ላይ ይከበራል። ይህ ዕለት እንዴት እና በምን ምክንያት መከበር ጀመረ?  "/><meta data-react-helmet="true" property="fb:app_id" content="1609039196070050"/><m
# ...

# %% [markdown]
# ## File/Webpage processing using <span style="color:blue">BeautifulSoup</span> library.
# This library can be used to process HTML and XML files.

# %%
# Install bs4 package
# !pip install beautifulsoup4

# %%
# Reading web content using BeautifulSoup
from bs4 import BeautifulSoup
page = requests.get("https://www.bbc.com/amharic/articles/cw4rwlpv98do")
soup = BeautifulSoup(page.content, 'html.parser')
# Display the content of the page - html
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="am">
#  <head>
#   <title data-react-helmet="true">
#    ዓለም አቀፉ የላብ አደሮች ቀን ለምን ሚያዝያ 23 ይከበራል? - BBC News አማርኛ
#   </title>
#   <meta content="IE=edge" data-react-helmet="true" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-react-helmet="true"/>
#   <meta content="noodp, noydir, max-image-preview:large" data-react-helmet="true" name="robots"/>
#   <meta content="#B80000" data-react-helmet="true" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" data-react-helmet="true" name="viewport"/>
#   <meta content="BBC News አማርኛ" data-react-helmet="true" name="apple-mobile-web-app-title"/>
#   <meta content="BBC News አማርኛ" data-react-helmet="true" name="application-name"/>
#   <meta content="ሜይ ዴይ በመባል በስፋት የሚታወቀው የዓለም ወዛደሮች (ላብአደሮች) ቀን በአውሮፓውያኑ አቆጣጠር በግንቦት ወር የመጀመሪያ ዕለት ላይ ይከበራል። ይህ ዕለት እንዴት እና በምን ምክንያት መከበር ጀመረ?  " data-react-helmet="true" name="description"/>
# ...

# %%
# Get only the text content of the page
print(soup.text)
# Out:
# ዓለም አቀፉ የላብ አደሮች ቀን ለምን ሚያዝያ 23 ይከበራል? - BBC News አማርኛBBC News, አማርኛወደ ዋናው ይዘት ይለፉክፍሎችዜናኢትዮጵያቪዲዮበጣም የተወደዱዜናኢትዮጵያቪዲዮበጣም የተወደዱዓለም አቀፉ የላብ አደሮች ቀን ለምን ሚያዝያ 23 ይከበራል?የፎቶው ባለመብት, AFPየምስሉ መግለጫ, ዕለቱ በበርካታ አገራት ሠራተኞች በሚያካሂዷቸው የተቃውሞ ሠልፎች ይታሰባል1 ግንቦት 2024ቀደም ሲል ሜይ ዴይ በበርካታ አገራት እንደ ጥንታዊ የፀደይ ፌስቲቫል ይታወቅ ነበር። አሁን ግን  በዓለም ዙሪያ ባሉ ሠራተኞች ያደረጉትን ታሪካዊ ትግሎች እና ጥቅሞችን ለማስታወስ የላብ አደሮች ቀን (ወይም ዓለም አቀፍ የላብ አደሮች ቀን) በመባል ይታወቃል።የተሻለ የሥራ ሁኔታ እና ለሠራተኛ ማኅበራት ተጨማሪ ድጋፍ የሚጠይቁ ሠልፎች በመላው ዓለም በየዓመቱ ይካሄዳሉ።መጀመሪያ አካባቢ በተለያዩ የሶሻሊስት እና የኮሚኒስት ድርጅቶች እና የሠራተኛ ቡድኖች ይዘወተር ነበር።ነገር ግን የመጀመሪያዎቹ ሰልፎች የተካሄዱት በዩናይትድ ስቴትስ ነበር።  ሰልፎቹ በመስከረም ወር የመጀመሪያው ሰኞ ይከናወኑ ነበር።የፎቶው ባለመብት, Getty Imagesእንዴት ተጀመረ?ብሪታኒያዊው የማኅበራዊ ተሃድሶ አራማጅ ሮበርት ኦውንን መሠረት በማድረግ በቀን ስምት ሰዓት ለመሥራት በመጠየቅ በአሜሪካ የሚገኙ የሠራተኛ ማኅበራት እአአ በ1986 ከተሞችን ያንቀጠቀጡ ሠልፎችን አካሄዱ።ኦውን “ስምንት ሰዓት ሥራ፣ ስምንት ሰዓት መዝናኛ፣ ስምንት ሰዓት እረፍት” በሚል የስምንት ሰዓት ሥራ ሃሳብን አነሳ።ትልቁ የሥራ ማቆም አድማ በቺካጎ ከተማ ሚያዝያ 23 የተካሄደ ሲሆን፣ 40 ሺህ ሠራተኞች እንደተሳተፉበት ይገመታል። በወቅቱ ያለምንም የሥራ ሰዓት ገደብ እና የእረፍት ቀናት ፋብሪካዎች ውስጥ ጠንክሮ መሥራት የተለመደ ነገር ነ
# ...

# %%
# list all the available elements in the page
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.Tag]

# %%
# The third (index 2) element is the HTML tag
print(list(soup.children)[1].name)
# get the sub-tags unde the HTML tag
html = list(soup.children)[1]
list(html.children) # contains the head and body sub tags
# Out:
# html
# ...

# %%
body = list(html.children)[1]
body
# Out:
# <body><div id="root"><div class="bbc-16ubpog" id="main-wrapper"><header role="banner"><div><div class="ep1mqcj0 bbc-1cc1evb e10yv9r12"><div class="bbc-1dg7u9h e10yv9r13"><a aria-labelledby="BrandLink-topPage" class="focusIndicatorRemove bbc-1x4x290 e10yv9r11" href="/amharic" id="topPage"><svg aria-hidden="true" class="bbc-1jefi8v e10yv9r10" focusable="false" height="32" id="brandSvgHeader" viewbox="140 140 1292 145" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" stroke="#000" stroke-width=".335" style="stroke:#fff"><path d="M759.927 265.75a4646.67 4646.67 0 00-23.49-37.242 2633.129 2633.129 0 00-23.49-36.2v73.442h-22.003V159.452h23.193a2668.556 2668.556 0 0123.713 36.052 2774.159 2774.159 0 0123.266 36.647v-72.699h22.003V265.75h-23.192zM804.186 159.452h73.145v19.03h-50.25v23.044h44.6v19.029h-44.6v26.166h53.075v19.03h-75.97V159.451zM982.1 265.75a3174.441 3174.441 0 01-9.886-35.978 3159.855 3159.855 0 01-9.441-35.977 2391.54 2391.54 0 01-9.218 35.977 2452.296 2452.296 0 01-9
# ...

# %%
# Get all the sub-tags under body
for tag in list(body.children):
    if tag.name:
        print (tag.name)
# Out:
# div
# script
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# div
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# ...

# %%
c = 1
for p in soup.find_all('p'):
    print(c,"-->",p.text)
    c += 1
# Out:
# 1 --> የፎቶው ባለመብት, AFP
# 2 --> ቀደም ሲል ሜይ ዴይ በበርካታ አገራት እንደ ጥንታዊ የፀደይ ፌስቲቫል ይታወቅ ነበር። አሁን ግን  በዓለም ዙሪያ ባሉ ሠራተኞች ያደረጉትን ታሪካዊ ትግሎች እና ጥቅሞችን ለማስታወስ የላብ አደሮች ቀን (ወይም ዓለም አቀፍ የላብ አደሮች ቀን) በመባል ይታወቃል።
# 3 --> የተሻለ የሥራ ሁኔታ እና ለሠራተኛ ማኅበራት ተጨማሪ ድጋፍ የሚጠይቁ ሠልፎች በመላው ዓለም በየዓመቱ ይካሄዳሉ።
# 4 --> መጀመሪያ አካባቢ በተለያዩ የሶሻሊስት እና የኮሚኒስት ድርጅቶች እና የሠራተኛ ቡድኖች ይዘወተር ነበር።
# 5 --> ነገር ግን የመጀመሪያዎቹ ሰልፎች የተካሄዱት በዩናይትድ ስቴትስ ነበር።  ሰልፎቹ በመስከረም ወር የመጀመሪያው ሰኞ ይከናወኑ ነበር።
# 6 --> የፎቶው ባለመብት, Getty Images
# 7 --> ብሪታኒያዊው የማኅበራዊ ተሃድሶ አራማጅ ሮበርት ኦውንን መሠረት በማድረግ በቀን ስምት ሰዓት ለመሥራት በመጠየቅ በአሜሪካ የሚገኙ የሠራተኛ ማኅበራት እአአ በ1986 ከተሞችን ያንቀጠቀጡ ሠልፎችን አካሄዱ።
# 8 --> ኦውን “ስምንት ሰዓት ሥራ፣ ስምንት ሰዓት መዝናኛ፣ ስምንት ሰዓት እረፍት” በሚል የስምንት ሰዓት ሥራ ሃሳብን አነሳ።
# 9 --> ትልቁ የሥራ ማቆም አድማ በቺካጎ ከተማ ሚያዝያ 23 የተካሄደ ሲሆን፣ 40 ሺህ ሠራተኞች እንደተሳተፉበት ይገመታል። በወቅቱ ያለምንም የሥራ ሰዓት ገደብ እና የእረፍት ቀናት ፋብሪካዎች ውስጥ ጠንክሮ መሥራት የተለመደ ነገር ነበር።
# 10 --> ቺካጎ የአሜሪካ ኢንዱስትሪ እና የሠራተኛ ማኅበር ማዕከል ነበረች።
# ...

# %% [markdown]
# # CSV writer and reader
# Lets read this wikipedia table that shows Ethiopian cities per population
# https://en.wikipedia.org/wiki/List_of_cities_and_towns_in_Ethiopia

# %%
# Read from online and write it to CSV
import csv
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("https://en.wikipedia.org/wiki/"
               "List_of_cities_and_towns_in_Ethiopia")
soup = BeautifulSoup(html, "html.parser")
table = soup.findAll("table", {"class":"wikitable"})[0]
rows = table.findAll("tr")
# Open a file for writing in text mode (not binarty)
with open("Ethiopian_cities_population.csv", "wt+", newline="") as f:
    # CSV file writer
    writer = csv.writer(f)
    for row in rows:
        csv_row = []
        for cell in row.findAll(["td", "th"]):
            csv_row.append(cell.get_text())
        writer.writerow(csv_row)

# %%
with open('Ethiopian_cities_population.csv') as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        print(', '.join(row))
# Out:
# Order
# , Name
# , Census1984
# , Census1994
# , Census2007[1]
# , Projected
# Estimate2016[2]
#
# , Region
# , Zone/Woreda
#
# 1., Addis Ababa, 1,412,575, 2,112,737, 2,739,551, 3,352,000, Addis Ababa Chartered City, Addis Ababa Chartered City
#
# 2., Dire Dawa, 61,583, 112,249, 207,044, 341,991, Federal, Dire dawa
#
# 3., Mekelle, 90,886, 120,249, 215,914, 340,859, Tigray, Mekelle Special Zone
#
# 4., Adama, 76,284, 127,842, 220,212, 338,940, Oromia, East Shewa Zone
#
# 5., Awassa, 36,169, 69,169, 157,139, 318,618, Sidama, Sidama Region
#
# 6., Bahir Dar, 54,800, 96,140, 155,428, 297,794, Amhara, Bahir Dar Special Zone
#
# 7., Gonder, 98,104, 164,851, 233,224, 285,000, Amhara, North Gonder zone Gonder City
#
# 8., Dessie, 68,848, 97,314, 120,095, 198,428, Amhara, Debub Wollo Zone
#
# 9., Jimma, 60,992, 88,867, 120,960, 186,148, Oromia, Jimma Special Zone
#
# 10., Jijiga, 23,183, 56,821, 125,876, 164,321, Somali, Fafan Zone
#
# ...

# %% [markdown]
# # Read/write using pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("Ethiopian_cities_population.csv")
df
# Out:
#     Order\n       Name\n Census1984\n Census1994\n Census2007[1]\n  \
# 0       1.0  Addis Ababa    1,412,575    2,112,737       2,739,551
# 1       2.0    Dire Dawa       61,583      112,249         207,044
# 2       3.0      Mekelle       90,886      120,249         215,914
# 3       4.0        Adama       76,284      127,842         220,212
# 4       5.0       Awassa       36,169       69,169         157,139
# ..      ...          ...          ...          ...             ...
# 66     67.0        Jinka          ...          ...          20,267
# 67     68.0      Dangila          ...          ...          24,827
# 68     69.0    Degehabur          ...       28,708          30,027
# 69     70.0        Dimtu          ...          ...          19,654
# 70     71.0        Agaro       18,764       23,246          25,258
#
#    Projected\nEstimate2016[2]\n\n                    Region\n  \
# 0                       3,352,000  Addis Ababa Chartered City
# ...

# %%
df.to_csv()
# Out:
# ',"Order\n","Name\n","Census1984\n","Census1994\n","Census2007[1]\n","Projected\nEstimate2016[2]\n\n","Region\n","Zone/Woreda\n"\n0,1.0,Addis Ababa,"1,412,575","2,112,737","2,739,551","3,352,000",Addis Ababa Chartered City,"Addis Ababa Chartered City\n"\n1,2.0,Dire Dawa,"61,583","112,249","207,044","341,991",Federal,"Dire dawa\n"\n2,3.0,Mekelle,"90,886","120,249","215,914","340,859",Tigray,"Mekelle Special Zone\n"\n3,4.0,Adama,"76,284","127,842","220,212","338,940",Oromia,"East Shewa Zone\n"\n4,5.0,Awassa,"36,169","69,169","157,139","318,618",Sidama,"Sidama Region\n"\n5,6.0,Bahir Dar,"54,800","96,140","155,428","297,794",Amhara,"Bahir Dar Special Zone\n"\n6,7.0,Gonder,"98,104","164,851","233,224","285,000",Amhara,"North Gonder zone Gonder City\n"\n7,8.0,Dessie,"68,848","97,314","120,095","198,428",Amhara,"Debub Wollo Zone\n"\n8,9.0,Jimma,"60,992","88,867","120,960","186,148",Oromia,"Jimma Special Zone\n"\n9,10.0,Jijiga,"23,183","56,821","125,876","164,321",Somali,"Fafan Zone\n"\n10,1
# ...

# %% [markdown]
# # <span style="color:red">Exercise</span>
#
# The Beautiful Soup reader seems that it has added the new line string (`\n`) to the header.
#
# 1. Remove `\n` character from the headers
# 1. Use the Pandas (pd) function (`df.to_csv()`) and write selected columns, namely, `Name`,`Projected_Estimate2016`, `Region`, and `Zone/Woreda`
